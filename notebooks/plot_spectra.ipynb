# %%
from nuztfpaper.spectra import plot_spectrum

# %%
spectra_sets = [
    (
        ("ZTF20abbpkpa_20200606_NOT_v1.ascii", 0.033, "SN2020lam"),
        ('2005cs_2005-07-02_00-00-00_Ekar_AFOSC_None.dat', 0.002, "SN2005cs (template IIP)"),
        None,
        "H"
        
    ),
    (
#         ("ZTF19abxtupj_20190928_Keck1_v1.ascii", 0.134, "SN2019pqh"),
        ("ztf19abxtupj_cut.txt", 0.134, "SN2019pqh"),
        ("1993J_1993-04-15_22-30-00_Ekar_BC-Ekar_SUSPECT.dat", 0.0001, "SN1993J (template IIb)"),
        ("spec-0391-51782-0220.fits", 0.134, "Host Galaxy (SDSS)"),
        "H"
    ),
    (
        ("ZTF20abdnpdo_20200612_NOT_v1.ascii", 0.041, "SN2020lls"),
        ("2004aw_2004-04-07_00-00-00_TNG_DOLORES_SUSPECT.dat", 0.0163, "SN2004aw (template Ic)"),
        None,
        None
    )
]

# %%
for (source_spectrum, comparison_spectrum, host_spectrum, plot_lines) in spectra_sets:
    plot_spectrum(
        source_spectrum=source_spectrum,
        comparison_spectrum=comparison_spectrum,
        host_spectrum=host_spectrum,
        plot_lines=plot_lines
    )
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# /Users/robertstein/Code/ztf_nu_paper_code/nuztfpaper/spectra.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   host["flux"][~mask] = 0.00
# /Users/robertstein/Code/ztf_nu_paper_code/nuztfpaper/spectra.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   host["flux"][~mask] = 0.00
